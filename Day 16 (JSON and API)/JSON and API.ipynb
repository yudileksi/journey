# %% [markdown]
# # JSON and API
#
# ## JSON
# *JavaScript Object Notation*
#
# it's a **universal format** for storing and sending data between differents systems
#
# almost every *API* on the internet sends and receives data in JSON format
#
# ## API
# *Application Programming Interface*
#
# it's the **way** for cpython code to *talk to another services* and request data or send data
